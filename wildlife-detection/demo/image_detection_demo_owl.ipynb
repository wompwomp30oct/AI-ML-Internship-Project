# %% [markdown]
# # Overhead Image Detection Demo with PytorchWildlife

# %% [markdown]
# This tutorial guides you on how to use PyTorchWildlife for image detection. We will go through the process of setting up the environment, defining the detection model, as well as performing inference and saving the results in different ways.
#
# ## Prerequisites
# Install PytorchWildlife running the following commands:
# ```bash
# conda create -n pytorch_wildlife python=3.10 -y
# conda activate pytorch_wildlife
# pip install PytorchWildlife
# ```
# Also, make sure you have a CUDA-capable GPU if you intend to run the model on a GPU. This notebook can also run on CPU.
#
# ## Importing libraries
# First, we'll start by importing the necessary libraries and modules.

# %%
import os
import torch
from PytorchWildlife.models import detection as pw_detection
from PytorchWildlife import utils as pw_utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 import torch
#       3 from PytorchWildlife.models import detection as pw_detection
#       4 from PytorchWildlife import utils as pw_utils
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ## Model Initialization
# We will initialize the OWL (Overhead Wildlife Locator) model for overhead image detection. This model is designed to locate and count dense herds in overhead images. Two variants are available:
# - **OWL-C**: CNN-only architecture (localization branch).
# - **OWL-T**: Hybrid CNN + Transformer architecture (multiscale residual).

# %%
# Setting the device to use for computations ('cuda' indicates GPU)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
# Model arguments and initialization
# OWL-C (CNN-only): General or Caribou version
#detection_model = pw_detection.OWLC(device=DEVICE)
#detection_model = pw_detection.OWLC(device=DEVICE, version="caribou")
# OWL-T (Hybrid CNN + Transformer):
detection_model = pw_detection.OWLT(device=DEVICE)

# %% [markdown]
# ## Single Image Detection
# We will first perform detection on a single image. Make sure to verify that you have the image in the specified path.

# %%
img_path = os.path.join(".","demo_data","owl_imgs","S_11_05_16_DSC01556_cut.JPG")
results = detection_model.single_image_detection(img=img_path)
pw_utils.save_detection_images_dots(results, os.path.join(".","owl_demo_output"), overwrite=False)

# %% [markdown]
# ## Batch Image Detection
# Next, we'll demonstrate how to process multiple images in batches. This is useful when you have a large number of images and want to process them efficiently.
# For OWL models, using batch size 1 is enough because each image is divided into patches.

# %%
folder_path = os.path.join(".","demo_data","owl_imgs")
results = detection_model.batch_image_detection(folder_path, batch_size=1)

# %% [markdown]
# ## Output Results
# PytorchWildlife allows to output detection results in multiple formats. Here are the examples:
#
# ### 1. Annotated Images:
# This will output the images with dots (instead of bounding boxes) drawn around the detected animals. The images will be saved in the specified output directory.

# %%
pw_utils.save_detection_images_dots(results, "owl_demo_batch_output", folder_path, overwrite=False)

# %% [markdown]
# ### 2. JSON Format:
# This will output the detection results in JSON format with dot coordinates (instead of bounding boxes). The JSON file will be saved in the specified output directory.

# %%
pw_utils.save_detection_json_as_dots(results, os.path.join(".","owl_demo_batch_output.json"),
                             categories=detection_model.CLASS_NAMES,
                             exclude_category_ids=[], # Category IDs can be found in the definition of each model.
                             exclude_file_path=None)

# %% [markdown]
# ### Copyright (c) Microsoft Corporation. All rights reserved.
# ### Licensed under the MIT License.
